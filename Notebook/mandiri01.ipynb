# %%
import pandas as pd

# Membaca data hour.csv dengan perintah read_csv dari pandas
df1 = pd.read_csv('../data/hour.csv', sep=',')

# Memilih kolom yang diinginkan dalam dataframe baru
df2 = df1[['instant', 'dteday', 'season', 'temp', 'hum', 'windspeed']]

# cetak header data (5 baris data)
df2.head()

# Simpan dataframe baru ke file CSV tanpa menyertakan index
df2.to_csv('../data/latihan01.csv', index=False)
